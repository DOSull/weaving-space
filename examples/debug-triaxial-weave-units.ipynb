# %%
# %matplotlib inline
import matplotlib.pyplot as pyplot
import geopandas as gpd
 
import sys
sys.path.insert(0, "../")
from weavingspace import WeaveUnit
from weavingspace import TileUnit
from weavingspace import Tiling

from weavingspace import tiling_utils

import shapely.geometry as geom
import shapely.affinity as affine

# %%
weave = WeaveUnit(weave_type = "twill", n = 2, 
                  spacing = 100, aspect = 1, strands = "ab|cd")
weave = WeaveUnit(weave_type = "cube", spacing = 500, 
                  aspect = 4/5, strands = "a|b|c")
ax = weave.plot(r = 0, figsize = (8, 8), show_reg_prototile = True, 
                show_ids = "id", show_vectors = False)

# %%
tile = weave.tiles.geometry[8]
print(tile)
# Out:
# POLYGON ((548.482756 50, 202.072594 -550, -259.807621 -550, 86.60254 50, 548.482756 50))

# %%
tiling_utils.get_interior_angles(tile), tiling_utils.get_side_lengths(tile)
# Out:
# ([np.float64(59.999999965176755),
#   np.float64(120.00000003482327),
#   np.float64(60.00000003679646),
#   np.float64(119.99999996320355)],
#  [692.8203232706632, 461.880215, 692.8203227706632, 461.880216])

# %%
print(tiling_utils.get_clean_polygon(tile))
# Out:
# POLYGON ((202.072594 -550, -259.807621 -550, 86.60254 50, 548.482756 50, 202.072594 -550))
