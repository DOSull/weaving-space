# %%
# %matplotlib inline

import geopandas as gpd

import sys
sys.path.insert(0, "../")
from weavingspace import TileUnit
from weavingspace import Tiling

# %%
ak = gpd.read_file("data/imd-auckland-2018.gpkg")

# %% [markdown]
# # Octagons (4.8.8)

# %%
d = 400
tile_unit = TileUnit(tiling_type = "archimedean", code = "4.8.8",
                     spacing = d, crs = ak.crs)
tile_unit.plot(r = 1)
# Out:
# <Axes: >

# %%
tiling = Tiling(tile_unit, ak, tiles_margin = 10)
# Out:
# Initialising Tiling: 9.164214134216309e-07
# Indexing the region: 0.004499624948948622
# Forming the region union: 0.3186670420691371
# Building the grid: 2.7124489578418434
# Making the tiles: 1.4695984590798616
# Indexing the tiles: 0.0012920000590384007

# %%
t = tiling.get_tiled_map()

# %%
t.vars_to_map = [x for x in ak if "Rank" in x]
t.n_classes = 5

fig = t.render(legend_zoom = 0.9, use_ellipse = True, 
               ellipse_magnification = 1.2)
# Out:
# No tile ids provided: setting all of them!
# Setting defaults for the 'categoricals' attribute of the map.
# No colour maps provided! Setting some defaults.
